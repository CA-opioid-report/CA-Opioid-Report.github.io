# %%
import pandas as pd 
import csv

# %%
df = pd.read_csv('median_household_income.csv')

# %%
columns_to_keep = ['NAME', 'S1903_C01_002E', 'S1903_C01_003E','S1903_C01_004E','S1903_C01_005E','S1903_C01_006E','S1903_C01_007E','S1903_C01_008E','S1903_C01_009E']
df = df[columns_to_keep]

# %%
df.rename(columns={'NAME':'County', 'S1903_C01_002E':'White', 'S1903_C01_003E':'Black or African American', 'S1903_C01_004E':'American Indian and Alaska Native', 'S1903_C01_005E':'Asian','S1903_C01_006E':'Native Hawaiian and Other Pacific Islander', 'S1903_C01_007E':'Some other race', 'S1903_C01_008E':'Two or more races', 'S1903_C01_009E':'Hispanic or Latino Origin'}, inplace=True)

#rename the columns

# %%
df.drop(0, inplace=True)

# %%
df

#use this for median household income by race
#reminder:row one is california, not county
# Out:
#                                 County    White Black or African American  \
# 1                           California  6425859                    814524
# 2           Alameda County, California   219402                     67979
# 3             Butte County, California    62666                         N
# 4      Contra Costa County, California   206142                     38738
# 5         El Dorado County, California    63122                         N
# 6            Fresno County, California   132805                     18160
# 7          Humboldt County, California    46015                         N
# 8          Imperial County, California    12209                         N
# 9              Kern County, California   145942                     14292
# 10            Kings County, California    19272                         N
# 11             Lake County, California    20764                         N
# 12      Los Angeles County, California  1252584                    311880
# ...

# %%
Madera = df.iloc[12]
print(Madera)

#retrieving data a row of data using iloc
# Out:
# County                                        Madera County, California
# White                                                             21561
# Black or African American                                             N
# American Indian and Alaska Native                                     N
# Asian                                                                 N
# Native Hawaiian and Other Pacific Islander                            N
# Some other race                                                   12047
# Two or more races                                                  7593
# Hispanic or Latino Origin                                         21318
# Name: 13, dtype: object

# %%
Monterey = df.iloc[16]
print(Monterey)

#retrieving data a row of data using iloc
# Out:
# County                                        Monterey County, California
# White                                                               58227
# Black or African American                                               N
# American Indian and Alaska Native                                       N
# Asian                                                                7718
# Native Hawaiian and Other Pacific Islander                              N
# Some other race                                                     45765
# Two or more races                                                   16512
# Hispanic or Latino Origin                                           63775
# Name: 17, dtype: object

# %%
Santa_Clara = df.iloc[31]
print(Santa_Clara)

#retrieving data a row of data using iloc
# Out:
# County                                        Santa Clara County, California
# White                                                                 242877
# Black or African American                                              15124
# American Indian and Alaska Native                                          N
# Asian                                                                 261684
# Native Hawaiian and Other Pacific Islander                                 N
# Some other race                                                        56931
# Two or more races                                                      70294
# Hispanic or Latino Origin                                             124682
# Name: 32, dtype: object

# %%
Santa_Barbara = df.iloc[30]
print(Santa_Barbara)

#retrieving data a row of data using iloc
# Out:
# County                                        Santa Barbara County, California
# White                                                                    91254
# Black or African American                                                    N
# American Indian and Alaska Native                                            N
# Asian                                                                     6687
# Native Hawaiian and Other Pacific Islander                                   N
# Some other race                                                          19066
# Two or more races                                                        27474
# Hispanic or Latino Origin                                                53408
# Name: 31, dtype: object

# %%
San_Mateo = df.iloc[29]
print(San_Mateo)

#retrieving data a row of data using iloc
# Out:
# County                                        San Mateo County, California
# White                                                               123564
# Black or African American                                             5174
# American Indian and Alaska Native                                        N
# Asian                                                                79960
# Native Hawaiian and Other Pacific Islander                               N
# Some other race                                                      20330
# Two or more races                                                    28631
# Hispanic or Latino Origin                                            47372
# Name: 30, dtype: object

# %%
Kings = df.iloc[9]
print(Kings)

#retrieving data a row of data using iloc
# Out:
# County                                        Kings County, California
# White                                                            19272
# Black or African American                                            N
# American Indian and Alaska Native                                    N
# Asian                                                                N
# Native Hawaiian and Other Pacific Islander                           N
# Some other race                                                   9856
# Two or more races                                                 8023
# Hispanic or Latino Origin                                        19737
# Name: 10, dtype: object

# %%
Yolo = df.iloc[41]
print(Yolo)

#retrieving data a row of data using iloc
#census for Mariposa, Mono, and Trinity is missing...oh wait...i should look at the highest number, not the lowest number
# Out:
# County                                        Yolo County, California
# White                                                           44501
# Black or African American                                           N
# American Indian and Alaska Native                                   N
# Asian                                                           10169
# Native Hawaiian and Other Pacific Islander                          N
# Some other race                                                  9721
# Two or more races                                               10560
# Hispanic or Latino Origin                                       20511
# Name: 42, dtype: object
